# %%
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# !apt-get install swig cmake freeglut3-dev

# %%
# !pip install pyglet==1.5.1

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !git clone https://github.com/DLR-RM/rl-baselines3-zoo

# %%
# !cd /content/rl-baselines3-zoo/

# %%
# !pip install setuptools==65.5.0
# !pip install -r requirements.txt
# Since colab uses Python 3.9 we need to add this installation
# !pip install gym[atari,accept-rom-license]==0.21.0

# %%
# !ls
# Out:
# benchmark.md  enjoy.py	   logs		   requirements.txt   setup.py
# CHANGELOG.md  hyperparams  Makefile	   rl-trained-agents  tests
# docker	      images	   pyproject.toml  rl_zoo3	      train.py
# docs	      LICENSE	   README.md	   scripts

# %%
# !cd hyperparams

# %%
# !ls
# Out:
# benchmark.md  enjoy.py	   logs		   requirements.txt   setup.py
# CHANGELOG.md  hyperparams  Makefile	   rl-trained-agents  tests
# docker	      images	   pyproject.toml  rl_zoo3	      train.py
# docs	      LICENSE	   README.md	   scripts

# %%
# !python train.py --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/
# Out:
# A streamkimeneten csak az utolsó 5000 sor látható.
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75e+03 |
# |    ep_rew_mean      | 331      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 244      |
# |    time_elapsed     | 2316     |
# |    total_timesteps  | 566206   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 116551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.82e+03 |
# |    ep_rew_mean      | 342      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 244      |
# |    time_elapsed     | 2324     |
# |    total_timesteps  | 567921   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0356   |
# |    n_updates        | 116980   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.83e+03 |
# |    ep_rew_mean      | 343      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 244      |
# |    time_elapsed     | 2328     |
# |    total_timesteps  | 569115   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 117278   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.84e+03 |
# |    ep_rew_mean      | 345      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 244      |
# |    time_elapsed     | 2333     |
# |    total_timesteps  | 570258   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 117564   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.88e+03 |
# |    ep_rew_mean      | 355      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 244      |
# |    time_elapsed     | 2336     |
# |    total_timesteps  | 571062   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0526   |
# |    n_updates        | 117765   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.87e+03 |
# |    ep_rew_mean      | 355      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 244      |
# |    time_elapsed     | 2341     |
# |    total_timesteps  | 572070   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0188   |
# |    n_updates        | 118017   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.89e+03 |
# |    ep_rew_mean      | 358      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 244      |
# |    time_elapsed     | 2345     |
# |    total_timesteps  | 573071   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.044    |
# |    n_updates        | 118267   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92e+03 |
# |    ep_rew_mean      | 363      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 244      |
# |    time_elapsed     | 2349     |
# |    total_timesteps  | 574128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 118531   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=336.00 +/- 95.78
# Episode length: 2927.20 +/- 525.56
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.93e+03 |
# |    mean_reward      | 336      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0329   |
# |    n_updates        | 118749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 368      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 243      |
# |    time_elapsed     | 2364     |
# |    total_timesteps  | 575525   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0406   |
# |    n_updates        | 118881   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.97e+03 |
# |    ep_rew_mean      | 373      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 243      |
# |    time_elapsed     | 2369     |
# |    total_timesteps  | 576835   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 119208   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3e+03    |
# |    ep_rew_mean      | 376      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 243      |
# |    time_elapsed     | 2374     |
# |    total_timesteps  | 577734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 119433   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3e+03    |
# |    ep_rew_mean      | 376      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 243      |
# |    time_elapsed     | 2379     |
# |    total_timesteps  | 579033   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 119758   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01e+03 |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 243      |
# |    time_elapsed     | 2382     |
# |    total_timesteps  | 579924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 119980   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 243      |
# |    time_elapsed     | 2388     |
# |    total_timesteps  | 581353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 120338   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 243      |
# |    time_elapsed     | 2394     |
# |    total_timesteps  | 582603   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 120650   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 243      |
# |    time_elapsed     | 2400     |
# |    total_timesteps  | 584125   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 121031   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 243      |
# |    time_elapsed     | 2402     |
# |    total_timesteps  | 584706   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0765   |
# |    n_updates        | 121176   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 243      |
# |    time_elapsed     | 2409     |
# |    total_timesteps  | 586246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0603   |
# |    n_updates        | 121561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 394      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 243      |
# |    time_elapsed     | 2416     |
# |    total_timesteps  | 587786   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 121946   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 243      |
# |    time_elapsed     | 2419     |
# |    total_timesteps  | 588763   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 122190   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 243      |
# |    time_elapsed     | 2423     |
# |    total_timesteps  | 589581   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 122395   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 243      |
# |    time_elapsed     | 2426     |
# |    total_timesteps  | 590253   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 122563   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 243      |
# |    time_elapsed     | 2430     |
# |    total_timesteps  | 591158   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 122789   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 243      |
# |    time_elapsed     | 2437     |
# |    total_timesteps  | 592977   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0532   |
# |    n_updates        | 123244   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 243      |
# |    time_elapsed     | 2442     |
# |    total_timesteps  | 594005   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 123501   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 243      |
# |    time_elapsed     | 2447     |
# |    total_timesteps  | 594956   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 123738   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 243      |
# |    time_elapsed     | 2452     |
# |    total_timesteps  | 596311   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 124077   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 243      |
# |    time_elapsed     | 2455     |
# |    total_timesteps  | 597093   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0507   |
# |    n_updates        | 124273   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 407      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 243      |
# |    time_elapsed     | 2459     |
# |    total_timesteps  | 598216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 124553   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 243      |
# |    time_elapsed     | 2464     |
# |    total_timesteps  | 599061   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 124765   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=495.00 +/- 134.83
# Episode length: 3589.60 +/- 403.06
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.59e+03 |
# |    mean_reward      | 495      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0219   |
# |    n_updates        | 124999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 242      |
# |    time_elapsed     | 2478     |
# |    total_timesteps  | 600052   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 125012   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 242      |
# |    time_elapsed     | 2486     |
# |    total_timesteps  | 601880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 125469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 242      |
# |    time_elapsed     | 2489     |
# |    total_timesteps  | 602777   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 125694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 242      |
# |    time_elapsed     | 2492     |
# |    total_timesteps  | 603625   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 125906   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 242      |
# |    time_elapsed     | 2497     |
# |    total_timesteps  | 604485   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 126121   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 242      |
# |    time_elapsed     | 2501     |
# |    total_timesteps  | 605403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 126350   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 242      |
# |    time_elapsed     | 2503     |
# |    total_timesteps  | 605917   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 126479   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 242      |
# |    time_elapsed     | 2507     |
# |    total_timesteps  | 607002   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 126750   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 242      |
# |    time_elapsed     | 2510     |
# |    total_timesteps  | 607836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0311   |
# |    n_updates        | 126958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 242      |
# |    time_elapsed     | 2514     |
# |    total_timesteps  | 608641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 127160   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 241      |
# |    time_elapsed     | 2519     |
# |    total_timesteps  | 609648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 127411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 242      |
# |    time_elapsed     | 2522     |
# |    total_timesteps  | 610543   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 127635   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 242      |
# |    time_elapsed     | 2525     |
# |    total_timesteps  | 611390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0337   |
# |    n_updates        | 127847   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 242      |
# |    time_elapsed     | 2528     |
# |    total_timesteps  | 612142   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0388   |
# |    n_updates        | 128035   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 241      |
# |    time_elapsed     | 2535     |
# |    total_timesteps  | 613370   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 128342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 241      |
# |    time_elapsed     | 2539     |
# |    total_timesteps  | 614418   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 128604   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3032     |
# |    fps              | 242      |
# |    time_elapsed     | 2543     |
# |    total_timesteps  | 615515   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0218   |
# |    n_updates        | 128878   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3036     |
# |    fps              | 242      |
# |    time_elapsed     | 2546     |
# |    total_timesteps  | 616339   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 129084   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3040     |
# |    fps              | 241      |
# |    time_elapsed     | 2552     |
# |    total_timesteps  | 617503   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 129375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3044     |
# |    fps              | 241      |
# |    time_elapsed     | 2556     |
# |    total_timesteps  | 618458   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 129614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3048     |
# |    fps              | 241      |
# |    time_elapsed     | 2560     |
# |    total_timesteps  | 619590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 129897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3052     |
# |    fps              | 241      |
# |    time_elapsed     | 2563     |
# |    total_timesteps  | 620368   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 130091   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3056     |
# |    fps              | 241      |
# |    time_elapsed     | 2567     |
# |    total_timesteps  | 621195   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 130298   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3060     |
# |    fps              | 241      |
# |    time_elapsed     | 2572     |
# |    total_timesteps  | 622153   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 130538   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3064     |
# |    fps              | 241      |
# |    time_elapsed     | 2578     |
# |    total_timesteps  | 623833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0469   |
# |    n_updates        | 130958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3068     |
# |    fps              | 241      |
# |    time_elapsed     | 2581     |
# |    total_timesteps  | 624783   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 131195   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=432.00 +/- 179.54
# Episode length: 3193.60 +/- 511.33
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.19e+03 |
# |    mean_reward      | 432      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0402   |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3072     |
# |    fps              | 241      |
# |    time_elapsed     | 2595     |
# |    total_timesteps  | 625548   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0219   |
# |    n_updates        | 131386   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3076     |
# |    fps              | 241      |
# |    time_elapsed     | 2599     |
# |    total_timesteps  | 626612   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 131652   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3080     |
# |    fps              | 240      |
# |    time_elapsed     | 2605     |
# |    total_timesteps  | 627859   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 131964   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3084     |
# |    fps              | 240      |
# |    time_elapsed     | 2608     |
# |    total_timesteps  | 628519   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0318   |
# |    n_updates        | 132129   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3088     |
# |    fps              | 241      |
# |    time_elapsed     | 2614     |
# |    total_timesteps  | 630094   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 132523   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3092     |
# |    fps              | 241      |
# |    time_elapsed     | 2618     |
# |    total_timesteps  | 631144   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 132785   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3096     |
# |    fps              | 240      |
# |    time_elapsed     | 2622     |
# |    total_timesteps  | 631954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 132988   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3100     |
# |    fps              | 240      |
# |    time_elapsed     | 2625     |
# |    total_timesteps  | 632647   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 133161   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3104     |
# |    fps              | 240      |
# |    time_elapsed     | 2629     |
# |    total_timesteps  | 633760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 133439   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3108     |
# |    fps              | 241      |
# |    time_elapsed     | 2636     |
# |    total_timesteps  | 635521   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00958  |
# |    n_updates        | 133880   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3112     |
# |    fps              | 240      |
# |    time_elapsed     | 2640     |
# |    total_timesteps  | 636205   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 134051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3116     |
# |    fps              | 240      |
# |    time_elapsed     | 2643     |
# |    total_timesteps  | 636966   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0453   |
# |    n_updates        | 134241   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3120     |
# |    fps              | 240      |
# |    time_elapsed     | 2646     |
# |    total_timesteps  | 637729   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 134432   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3124     |
# |    fps              | 241      |
# |    time_elapsed     | 2652     |
# |    total_timesteps  | 639340   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 134834   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3128     |
# |    fps              | 240      |
# |    time_elapsed     | 2656     |
# |    total_timesteps  | 640120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 135029   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3132     |
# |    fps              | 240      |
# |    time_elapsed     | 2661     |
# |    total_timesteps  | 641104   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0393   |
# |    n_updates        | 135275   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3136     |
# |    fps              | 240      |
# |    time_elapsed     | 2664     |
# |    total_timesteps  | 641891   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0423   |
# |    n_updates        | 135472   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3140     |
# |    fps              | 240      |
# |    time_elapsed     | 2668     |
# |    total_timesteps  | 642937   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 135734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3144     |
# |    fps              | 240      |
# |    time_elapsed     | 2672     |
# |    total_timesteps  | 644036   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 136008   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3148     |
# |    fps              | 240      |
# |    time_elapsed     | 2678     |
# |    total_timesteps  | 645171   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 136292   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3152     |
# |    fps              | 240      |
# |    time_elapsed     | 2683     |
# |    total_timesteps  | 646512   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0416   |
# |    n_updates        | 136627   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3156     |
# |    fps              | 240      |
# |    time_elapsed     | 2688     |
# |    total_timesteps  | 647706   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 136926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3160     |
# |    fps              | 240      |
# |    time_elapsed     | 2696     |
# |    total_timesteps  | 649271   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 137317   |
# ----------------------------------
# Eval num_timesteps=650000, episode_reward=458.00 +/- 128.16
# Episode length: 3241.00 +/- 656.43
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.24e+03 |
# |    mean_reward      | 458      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 650000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0618   |
# |    n_updates        | 137499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3164     |
# |    fps              | 240      |
# |    time_elapsed     | 2709     |
# |    total_timesteps  | 650394   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 137598   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 407      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3168     |
# |    fps              | 239      |
# |    time_elapsed     | 2714     |
# |    total_timesteps  | 651409   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 137852   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3172     |
# |    fps              | 240      |
# |    time_elapsed     | 2719     |
# |    total_timesteps  | 652690   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 138172   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3176     |
# |    fps              | 240      |
# |    time_elapsed     | 2723     |
# |    total_timesteps  | 653667   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 138416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3180     |
# |    fps              | 239      |
# |    time_elapsed     | 2728     |
# |    total_timesteps  | 654788   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00565  |
# |    n_updates        | 138696   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3184     |
# |    fps              | 239      |
# |    time_elapsed     | 2734     |
# |    total_timesteps  | 656120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 139029   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3188     |
# |    fps              | 240      |
# |    time_elapsed     | 2740     |
# |    total_timesteps  | 657762   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 139440   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3192     |
# |    fps              | 239      |
# |    time_elapsed     | 2746     |
# |    total_timesteps  | 659061   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 139765   |
# ----------------------------------
# ----------------------------------
# ...
# |    loss             | 0.00934  |
# |    n_updates        | 214157   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3996     |
# |    fps              | 231      |
# |    time_elapsed     | 4141     |
# |    total_timesteps  | 957994   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0382   |
# |    n_updates        | 214498   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4000     |
# |    fps              | 231      |
# |    time_elapsed     | 4145     |
# |    total_timesteps  | 958851   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 214712   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4004     |
# |    fps              | 231      |
# |    time_elapsed     | 4149     |
# |    total_timesteps  | 959999   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 214999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 594      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4008     |
# |    fps              | 231      |
# |    time_elapsed     | 4159     |
# |    total_timesteps  | 962088   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 215521   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 593      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4012     |
# |    fps              | 231      |
# |    time_elapsed     | 4165     |
# |    total_timesteps  | 963607   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 215901   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 593      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4016     |
# |    fps              | 231      |
# |    time_elapsed     | 4172     |
# |    total_timesteps  | 965258   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 216314   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 594      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4020     |
# |    fps              | 231      |
# |    time_elapsed     | 4178     |
# |    total_timesteps  | 966646   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 216661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 589      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4024     |
# |    fps              | 231      |
# |    time_elapsed     | 4181     |
# |    total_timesteps  | 967216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00966  |
# |    n_updates        | 216803   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4028     |
# |    fps              | 231      |
# |    time_elapsed     | 4188     |
# |    total_timesteps  | 969263   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 217315   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4032     |
# |    fps              | 231      |
# |    time_elapsed     | 4195     |
# |    total_timesteps  | 970457   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 217614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 588      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4036     |
# |    fps              | 231      |
# |    time_elapsed     | 4200     |
# |    total_timesteps  | 971788   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.01     |
# |    n_updates        | 217946   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 588      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4040     |
# |    fps              | 231      |
# |    time_elapsed     | 4206     |
# |    total_timesteps  | 973547   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 218386   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4044     |
# |    fps              | 231      |
# |    time_elapsed     | 4213     |
# |    total_timesteps  | 974892   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00945  |
# |    n_updates        | 218722   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=793.00 +/- 289.70
# Episode length: 4167.20 +/- 1455.59
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.17e+03 |
# |    mean_reward      | 793      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 218749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4048     |
# |    fps              | 230      |
# |    time_elapsed     | 4235     |
# |    total_timesteps  | 977272   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 219317   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 612      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4052     |
# |    fps              | 230      |
# |    time_elapsed     | 4246     |
# |    total_timesteps  | 979783   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 219945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 612      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4056     |
# |    fps              | 230      |
# |    time_elapsed     | 4253     |
# |    total_timesteps  | 981538   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 220384   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 614      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4060     |
# |    fps              | 230      |
# |    time_elapsed     | 4260     |
# |    total_timesteps  | 983362   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 220840   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 621      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4064     |
# |    fps              | 230      |
# |    time_elapsed     | 4269     |
# |    total_timesteps  | 985109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 221277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 625      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4068     |
# |    fps              | 230      |
# |    time_elapsed     | 4273     |
# |    total_timesteps  | 986245   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 221561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 623      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4072     |
# |    fps              | 230      |
# |    time_elapsed     | 4281     |
# |    total_timesteps  | 988140   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 222034   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 620      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4076     |
# |    fps              | 230      |
# |    time_elapsed     | 4287     |
# |    total_timesteps  | 989405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 222351   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 622      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4080     |
# |    fps              | 230      |
# |    time_elapsed     | 4291     |
# |    total_timesteps  | 990346   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00646  |
# |    n_updates        | 222586   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 622      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4084     |
# |    fps              | 230      |
# |    time_elapsed     | 4299     |
# |    total_timesteps  | 992182   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 223045   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 618      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4088     |
# |    fps              | 230      |
# |    time_elapsed     | 4303     |
# |    total_timesteps  | 993053   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 223263   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 614      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4092     |
# |    fps              | 230      |
# |    time_elapsed     | 4309     |
# |    total_timesteps  | 994610   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0365   |
# |    n_updates        | 223652   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 614      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4096     |
# |    fps              | 230      |
# |    time_elapsed     | 4313     |
# |    total_timesteps  | 995538   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 223884   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 612      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4100     |
# |    fps              | 230      |
# |    time_elapsed     | 4320     |
# |    total_timesteps  | 996995   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0274   |
# |    n_updates        | 224248   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4104     |
# |    fps              | 230      |
# |    time_elapsed     | 4325     |
# |    total_timesteps  | 998378   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0931   |
# |    n_updates        | 224594   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=477.00 +/- 117.12
# Episode length: 3919.60 +/- 539.26
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.92e+03 |
# |    mean_reward      | 477      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_2

# %%
# !python enjoy.py  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2023-04-04 23:31:24.859633: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 23:31:25.782731: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Atari Episode Score: 800.00
# Atari Episode Length 3918
# Atari Episode Score: 600.00
# Atari Episode Length 3790
# Atari Episode Score: 880.00
# Atari Episode Length 6354
# Atari Episode Score: 525.00
# Atari Episode Length 4016

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name DQNSpaceInvadersNoFrameskip  -orga Bandika  -f logs/
# Out:
# 2023-04-04 23:35:14.271046: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 23:35:15.161333: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to Bandika/DQNSpaceInvadersNoFrameskip, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Cloning https://huggingface.co/Bandika/DQNSpaceInvadersNoFrameskip into local empty directory.
# Saving model to: hub/DQNSpaceInvadersNoFrameskip/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmpu396j9jd/-step-0-to-step-1000.mp4
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpu396j9jd/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.37, start: 0.000000, bitrate: 47 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 160x210, 44 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f2bb9cd2c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f2bb9cd2c0] profile High, level 1.2
# [libx264 @ 0x55f2bb9cd2c0] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub/DQNSpaceInvadersNoFrameskip/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 160x210, q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 1001 fps=0.0 q=-1.0 Lsize=     187kB time=00:00:33.26 bitrate=  46.0kbits/s speed=42.2x
# video:175kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.954423%
# [libx264 @ 0x55f2bb9cd2c0] frame I:5     Avg QP:15.84  size:  3473
# [libx264 @ 0x55f2bb9cd2c0] frame P:327   Avg QP:23.26  size:   389
# [libx264 @ 0x55f2bb9cd2c0] frame B:669   Avg QP:30.24  size:    50
# [libx264 @ 0x55f2bb9cd2c0] consecutive B-frames:  5.7% 12.4%  9.6% 72.3%
# [libx264 @ 0x55f2bb9cd2c0] mb I  I16..4: 28.0% 31.9% 40.1%
# [libx264 @ 0x55f2bb9cd2c0] mb P  I16..4:  0.6%  1.3%  1.1%  P16..4:  7.9%  2.9%  2.0%  0.0%  0.0%    skip:84.1%
# [libx264 @ 0x55f2bb9cd2c0] mb B  I16..4:  0.2%  0.2%  0.1%  B16..8:  9.7%  0.5%  0.0%  direct: 0.1%  skip:89.1%  L0:44.0% L1:55.8% BI: 0.2%
# [libx264 @ 0x55f2bb9cd2c0] 8x8 transform intra:37.1% inter:4.9%
# [libx264 @ 0x55f2bb9cd2c0] coded y,uvDC,uvAC intra: 21.0% 33.6% 31.3% inter: 1.2% 1.5% 1.2%
# [libx264 @ 0x55f2bb9cd2c0] i16 v,h,dc,p: 37% 59%  4%  0%
# [libx264 @ 0x55f2bb9cd2c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23%  7% 69%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x55f2bb9cd2c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 12% 42%  2%  2%  3%  1%  3%  1%
# [libx264 @ 0x55f2bb9cd2c0] i8c dc,h,v,p: 58% 29% 11%  2%
# [libx264 @ 0x55f2bb9cd2c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f2bb9cd2c0] ref P L0: 68.4%  6.0% 13.0% 12.6%
# [libx264 @ 0x55f2bb9cd2c0] ref B L0: 77.9% 18.4%  3.6%
# [libx264 @ 0x55f2bb9cd2c0] ref B L1: 95.0%  5.0%
# [libx264 @ 0x55f2bb9cd2c0] kb/s:42.75
# ℹ Pushing repo DQNSpaceInvadersNoFrameskip to the Hugging Face Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 1.00/26.0M [00:00<?, ?B/s]
# Upload file replay.mp4:   0% 1.00/187k [00:00<?, ?B/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth:   0% 1.00/431 [00:00<?, ?B/s]
#
#
#
# Upload file train_eval_metrics.zip:   0% 1.00/37.1k [00:00<?, ?B/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 15.3MB [00:01, 16.0MB/s]
#
#
#
# Upload file train_eval_metrics.zip: 15.3MB [00:01, 16.0MB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  59% 15.3M/26.0M [00:03<00:02, 5.33MB/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 15.3MB [00:03, 5.33MB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 30.5MB [00:07, 4.45MB/s]                To https://huggingface.co/Bandika/DQNSpaceInvadersNoFrameskip
#    2feb5bb..d1c2602  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 26.0M/26.0M [00:09<00:00, 3.02MB/s]
#
# Upload file replay.mp4: 100% 187k/187k [00:09<00:00, 21.2kB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100% 12.9M/12.9M [00:09<00:00, 1.50MB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 431/431 [00:09<00:00, 47.7B/s]
#
#
#
#
# Upload file train_eval_metrics.zip: 100% 37.1k/37.1k [00:09<00:00, 4.22kB/s]
#
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100% 12.9M/12.9M [00:09<00:00, 1.50MB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/Bandika/DQNSpaceInvadersNoFrameskip
