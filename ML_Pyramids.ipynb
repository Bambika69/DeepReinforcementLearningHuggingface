# %%
# %%capture
# Clone the repository
# !git clone --depth 1 --branch hf-integration https://github.com/huggingface/ml-agents

# %%
# %%capture
# Go inside the repository and install the package
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %%
# %%capture
# Due to some conflicts between mlagents and tensorflow we need to uninstall it
# !pip3 uninstall tensorflow -y

# %%
# Here, we create training-envs-executables and linux
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H" -O ./training-envs-executables/linux/Pyramids.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-04-15 16:09:36--  https://docs.google.com/uc?export=download&confirm=t&id=1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H
# Resolving docs.google.com (docs.google.com)... 74.125.200.102, 74.125.200.113, 74.125.200.100, ...
# Connecting to docs.google.com (docs.google.com)|74.125.200.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1ckpgsgv645jvmr5q8m872uuo6uukl64/1681574925000/09764732090272539193/*/1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H?e=download&uuid=3bf7e254-5d8d-47a2-bcda-af9e490f059c [following]
# Warning: wildcards not supported in HTTP.
# --2023-04-15 16:09:36--  https://doc-04-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1ckpgsgv645jvmr5q8m872uuo6uukl64/1681574925000/09764732090272539193/*/1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H?e=download&uuid=3bf7e254-5d8d-47a2-bcda-af9e490f059c
# Resolving doc-04-8c-docs.googleusercontent.com (doc-04-8c-docs.googleusercontent.com)... 142.250.4.132, 2404:6800:4003:c06::84
# Connecting to doc-04-8c-docs.googleusercontent.com (doc-04-8c-docs.googleusercontent.com)|142.250.4.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42907187 (41M) [application/zip]
# Saving to: ‘./training-envs-executables/linux/Pyramids.zip’
#
# ./training-envs-exe 100%[===================>]  40.92M  45.3MB/s    in 0.9s
#
# 2023-04-15 16:09:38 (45.3 MB/s) - ‘./training-envs-executables/linux/Pyramids.zip’ saved [42907187/42907187]

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/Pyramids.zip

# %%
# !chmod -R 755 ./training-envs-executables/linux/Pyramids/Pyramids

# %% [markdown]
# For our benchmark we modify the ./content/ml-agents/config/ppo/PyramidsRND.yaml file to train for only 1M steps "max_steps"

# %%
# !mlagents-learn ./config/ppo/PyramidsRND.yaml --env=./training-envs-executables/linux/Pyramids/Pyramids --run-id="Pyramids Training" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.31.0.dev0,
#   ml-agents-envs: 0.31.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.11.0+cu102
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Pyramids?team=0
# [INFO] Hyperparameters for behavior name Pyramids:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	128
# 	  buffer_size:	2048
# 	  learning_rate:	0.0003
# 	  beta:	0.01
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	500000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.01
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	64
# 	      num_layers:	3
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	5
# 	even_checkpoints:	False
# 	max_steps:	1000000
# 	time_horizon:	128
# 	summary_freq:	30000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Pyramids. Step: 30000. Time Elapsed: 67.455 s. Mean Reward: -0.875. Std of Reward: 0.502. Training.
# [INFO] Pyramids. Step: 60000. Time Elapsed: 128.030 s. Mean Reward: -1.000. Std of Reward: 0.000. Training.
# [INFO] Pyramids. Step: 90000. Time Elapsed: 189.413 s. Mean Reward: -0.932. Std of Reward: 0.384. Training.
# [INFO] Pyramids. Step: 120000. Time Elapsed: 249.751 s. Mean Reward: -0.775. Std of Reward: 0.717. Training.
# [INFO] Pyramids. Step: 150000. Time Elapsed: 316.984 s. Mean Reward: -0.798. Std of Reward: 0.628. Training.
# [INFO] Pyramids. Step: 180000. Time Elapsed: 382.330 s. Mean Reward: -0.159. Std of Reward: 1.061. Training.
# [INFO] Pyramids. Step: 210000. Time Elapsed: 450.349 s. Mean Reward: -0.124. Std of Reward: 1.148. Training.
# [INFO] Pyramids. Step: 240000. Time Elapsed: 514.542 s. Mean Reward: -0.139. Std of Reward: 1.158. Training.
# [INFO] Pyramids. Step: 270000. Time Elapsed: 580.181 s. Mean Reward: 0.144. Std of Reward: 1.219. Training.
# [INFO] Pyramids. Step: 300000. Time Elapsed: 650.063 s. Mean Reward: 0.695. Std of Reward: 1.197. Training.
# [INFO] Pyramids. Step: 330000. Time Elapsed: 720.088 s. Mean Reward: 1.054. Std of Reward: 1.036. Training.
# [INFO] Pyramids. Step: 360000. Time Elapsed: 790.858 s. Mean Reward: 0.973. Std of Reward: 1.132. Training.
# [INFO] Pyramids. Step: 390000. Time Elapsed: 862.223 s. Mean Reward: 1.080. Std of Reward: 1.021. Training.
# [INFO] Pyramids. Step: 420000. Time Elapsed: 935.760 s. Mean Reward: 1.286. Std of Reward: 0.928. Training.
# [INFO] Pyramids. Step: 450000. Time Elapsed: 1008.980 s. Mean Reward: 1.150. Std of Reward: 1.012. Training.
# [INFO] Pyramids. Step: 480000. Time Elapsed: 1083.093 s. Mean Reward: 1.266. Std of Reward: 0.800. Training.
# [INFO] Exported results/Pyramids Training/Pyramids/Pyramids-499913.onnx
# [INFO] Pyramids. Step: 510000. Time Elapsed: 1158.774 s. Mean Reward: 1.352. Std of Reward: 0.830. Training.
# [INFO] Pyramids. Step: 540000. Time Elapsed: 1230.284 s. Mean Reward: 1.498. Std of Reward: 0.686. Training.
# [INFO] Pyramids. Step: 570000. Time Elapsed: 1306.562 s. Mean Reward: 1.447. Std of Reward: 0.665. Training.
# [INFO] Pyramids. Step: 600000. Time Elapsed: 1382.882 s. Mean Reward: 1.606. Std of Reward: 0.454. Training.
# [INFO] Pyramids. Step: 630000. Time Elapsed: 1461.942 s. Mean Reward: 1.517. Std of Reward: 0.669. Training.
# [INFO] Pyramids. Step: 660000. Time Elapsed: 1544.724 s. Mean Reward: 1.656. Std of Reward: 0.325. Training.
# [INFO] Pyramids. Step: 690000. Time Elapsed: 1619.899 s. Mean Reward: 1.600. Std of Reward: 0.453. Training.
# [INFO] Pyramids. Step: 720000. Time Elapsed: 1699.023 s. Mean Reward: 1.664. Std of Reward: 0.330. Training.
# [INFO] Pyramids. Step: 750000. Time Elapsed: 1777.496 s. Mean Reward: 1.633. Std of Reward: 0.494. Training.
# [INFO] Pyramids. Step: 780000. Time Elapsed: 1858.118 s. Mean Reward: 1.669. Std of Reward: 0.430. Training.
# [INFO] Pyramids. Step: 810000. Time Elapsed: 1939.530 s. Mean Reward: 1.611. Std of Reward: 0.561. Training.
# [INFO] Pyramids. Step: 840000. Time Elapsed: 2020.127 s. Mean Reward: 1.644. Std of Reward: 0.422. Training.
# [INFO] Pyramids. Step: 870000. Time Elapsed: 2103.807 s. Mean Reward: 1.711. Std of Reward: 0.176. Training.
# [INFO] Pyramids. Step: 900000. Time Elapsed: 2187.482 s. Mean Reward: 1.722. Std of Reward: 0.292. Training.
# [INFO] Pyramids. Step: 930000. Time Elapsed: 2271.533 s. Mean Reward: 1.716. Std of Reward: 0.179. Training.
# [INFO] Pyramids. Step: 960000. Time Elapsed: 2350.580 s. Mean Reward: 1.681. Std of Reward: 0.401. Training.
# [INFO] Pyramids. Step: 990000. Time Elapsed: 2434.191 s. Mean Reward: 1.717. Std of Reward: 0.374. Training.
# [INFO] Exported results/Pyramids Training/Pyramids/Pyramids-999940.onnx
# [INFO] Exported results/Pyramids Training/Pyramids/Pyramids-1000068.onnx
# [INFO] Copied results/Pyramids Training/Pyramids/Pyramids-1000068.onnx to results/Pyramids Training/Pyramids.onnx.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !mlagents-push-to-hf  --run-id="Pyramids Training" --local-dir="./results/Pyramids Training"  --repo-id="Bandika/PPOPyramids" --commit-message="First training of Pyramids"
# Out:
# Cloning https://huggingface.co/Bandika/PPOPyramids into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/Bandika/PPOPyramids into local empty directory.
# Upload file Pyramids/Pyramids-1000068.pt:   0% 32.0k/8.25M [00:00<?, ?B/s]
# Upload file Pyramids/events.out.tfevents.1681575232.b98a9cf04dd2.2224.0:  10% 32.0k/307k [00:00<?, ?B/s]
#
# Upload file Pyramids.onnx:   2% 32.0k/1.35M [00:00<?, ?B/s]
#
#
# Upload file Pyramids/Pyramids-499913.onnx:   2% 32.0k/1.35M [00:00<?, ?B/s]
#
#
#
# Upload file Pyramids/Pyramids-499913.pt:   0% 32.0k/8.25M [00:00<?, ?B/s]
#
#
#
#
# Upload file Pyramids/Pyramids-1000068.pt:  10% 864k/8.25M [00:01<00:09, 850kB/s]
#
# Upload file Pyramids.onnx:  16% 224k/1.35M [00:01<00:06, 196kB/s]
# Upload file Pyramids/events.out.tfevents.1681575232.b98a9cf04dd2.2224.0:  73% 224k/307k [00:01<00:00, 196kB/s]
#
#
# Upload file Pyramids/Pyramids-499913.onnx:  16% 224k/1.35M [00:01<00:06, 196kB/s]
#
#
#
#
# Upload file Pyramids/Pyramids-999940.pt:   3% 224k/8.25M [00:01<00:42, 196kB/s]
#
#
#
# Upload file Pyramids/Pyramids-1000068.pt:  87% 7.16M/8.25M [00:02<00:00, 4.23MB/s]
#
#
# Upload file Pyramids/Pyramids-499913.onnx: 100% 1.35M/1.35M [00:02<00:00, 778kB/s]
#
#
#
#
# Upload file Pyramids/Pyramids-999940.pt:  20% 1.62M/8.25M [00:02<00:07, 946kB/s]
#
#
#
# Upload file Pyramids/Pyramids-499913.pt:  20% 1.62M/8.25M [00:02<00:07, 946kB/s]
#
#
#
# Upload file Pyramids/Pyramids-499913.pt:  75% 6.16M/8.25M [00:03<00:00, 2.68MB/s]
#
#
#
#
# Upload file Pyramids/Pyramids-999940.pt:  75% 6.19M/8.25M [00:03<00:00, 2.69MB/s]To https://huggingface.co/Bandika/PPOPyramids
#    9d11f32..ee9a408  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/Bandika/PPOPyramids
#    9d11f32..ee9a408  main -> main
#
# Upload file Pyramids/Pyramids-1000068.pt: 100% 8.25M/8.25M [00:04<00:00, 2.15MB/s]
#
# Upload file Pyramids/events.out.tfevents.1681575232.b98a9cf04dd2.2224.0: 100% 307k/307k [00:04<00:00, 60.1kB/s]
# Upload file Pyramids/events.out.tfevents.1681575232.b98a9cf04dd2.2224.0: 100% 307k/307k [00:04<00:00, 70.3kB/s]
#
#
# Upload file Pyramids.onnx: 100% 1.35M/1.35M [00:04<00:00, 358kB/s]
#
# Upload file Pyramids.onnx: 100% 1.35M/1.35M [00:04<00:00, 345kB/s]
#
#
#
# Upload file Pyramids/Pyramids-499913.onnx: 100% 1.35M/1.35M [00:04<00:00, 345kB/s]
#
#
#
#
# Upload file Pyramids/Pyramids-499913.pt: 100% 8.25M/8.25M [00:04<00:00, 2.49MB/s]
#
#
#
# Upload file Pyramids/Pyramids-499913.pt: 100% 8.25M/8.25M [00:04<00:00, 2.15MB/s]
#
#
#
#
#
# Upload file Pyramids/Pyramids-999940.pt: 100% 8.25M/8.25M [00:04<00:00, 2.48MB/s]
#
#
#
#
# Upload file Pyramids/Pyramids-999940.pt: 100% 8.25M/8.25M [00:04<00:00, 2.15MB/s]
#
#  Your model is pushed to the hub. You can view your model here: https://huggingface.co/Bandika/PPOPyramids
